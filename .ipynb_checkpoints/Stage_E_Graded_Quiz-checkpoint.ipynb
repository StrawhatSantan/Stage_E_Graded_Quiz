# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Time_series_analysis_and_forecast_DATASET.csv')
df.head()
# Out:
#               FullDate  Tmax   SysLoad  GasPrice  ElecPrice
# 0  2010-09-01 00:00:00  15.8  1688.215      3.69     23.710
# 1  2010-09-01 01:00:00  15.8  1669.195      3.69     22.635
# 2  2010-09-01 02:00:00  15.8  1491.980      3.69     22.565
# 3  2010-09-01 03:00:00  15.8  1330.760      3.69     18.910
# 4  2010-09-01 04:00:00  15.8  1247.940      3.69     18.030

# %% [markdown]
# To check number of missing data

# %%
df.isnull().sum()
# Out:
# FullDate     0
# Tmax         0
# SysLoad      0
# GasPrice     0
# ElecPrice    0
# dtype: int64

# %% [markdown]
# Converting FullDate into datetime format

# %%
df['FullDate'] = pd.to_datetime(df['FullDate'])
df.head()
# Out:
#              FullDate  Tmax   SysLoad  GasPrice  ElecPrice
# 0 2010-09-01 00:00:00  15.8  1688.215      3.69     23.710
# 1 2010-09-01 01:00:00  15.8  1669.195      3.69     22.635
# 2 2010-09-01 02:00:00  15.8  1491.980      3.69     22.565
# 3 2010-09-01 03:00:00  15.8  1330.760      3.69     18.910
# 4 2010-09-01 04:00:00  15.8  1247.940      3.69     18.030

# %% [markdown]
# Setting Index as FullDate

# %%
df.set_index('FullDate', inplace = True)
df.head()
# Out:
#                      Tmax   SysLoad  GasPrice  ElecPrice
# FullDate
# 2010-09-01 00:00:00  15.8  1688.215      3.69     23.710
# 2010-09-01 01:00:00  15.8  1669.195      3.69     22.635
# 2010-09-01 02:00:00  15.8  1491.980      3.69     22.565
# 2010-09-01 03:00:00  15.8  1330.760      3.69     18.910
# 2010-09-01 04:00:00  15.8  1247.940      3.69     18.030

# %% [markdown]
# Using Daily Sampling rate i.e Downsampling from hourly to daily

# %%
df_daily = df.resample('M').mean()
df_daily.head()
# Out:
#                  Tmax      SysLoad  GasPrice   ElecPrice
# FullDate
# 2010-09-30  16.906667  1578.145819  3.578663   25.075896
# 2010-10-31  21.377419  1398.027708  2.799987   22.223629
# 2010-11-30  24.323333  1484.759104  2.321943   22.575944
# 2010-12-31  26.696774  1082.167586  2.401429   17.585753
# 2011-01-31  30.629032  1331.477822  2.917977  103.094603

# %% [markdown]
# Plotting Data ElecPrice (y) against FullDate (dt)

# %%
plt.figure(figsize = (10, 6))
plt.plot(df_daily.index, df_daily.ElecPrice, '--', marker = '*')
plt.grid()
plt.xlabel('Date')
plt.ylabel('ElecPrice')
plt.title('Plotting Data ElecPrice (y) against FullDate (dt)')
# Out:
# Text(0.5, 1.0, 'Plotting Data ElecPrice (y) against FullDate (dt)')

# %% [markdown]
# #### Calculating Pearson's Correlation

# %% [markdown]
# For Tmax against SysLoad

# %%
from scipy.stats import pearsonr
corr, _ = pearsonr(df_daily.Tmax, df_daily.SysLoad)
print(f'Pearsons correlation = {round(corr, 3)}')
# Out:
# Pearsons correlation = -0.12

# %% [markdown]
# For Tmax against GasPrice

# %%
from scipy.stats import pearsonr
corr, _ = pearsonr(df_daily.Tmax, df_daily.GasPrice)
print(f'Pearsons correlation = {round(corr, 3)}')
# Out:
# Pearsons correlation = 0.136

# %% [markdown]
# For SysLoad against GasPrice

# %%
from scipy.stats import pearsonr
corr, _ = pearsonr(df_daily.Tmax, df_daily.GasPrice)
print(f'Pearsons correlation = {round(corr, 3)}')
# Out:
# Pearsons correlation = 0.136

# %% [markdown]
# #### EDA for Time Series

# %% [markdown]
# Graphing dataset to show observed, residual, seasonality and trend

# %%
import statsmodels.api as sm
from pylab import rcParams
rcParams['figure.figsize'] = 15, 8
decompose_series = sm.tsa.seasonal_decompose(df['ElecPrice'], model = 'additive')
decompose_series.plot()
plt.show()

# %%
import statsmodels.api as sm
from pylab import rcParams
rcParams['figure.figsize'] = 10, 8
decompose_series = sm.tsa.seasonal_decompose(df_daily['ElecPrice'], model = 'additive')
decompose_series.plot()
plt.show()

# %% [markdown]
# Performing Augumented Dickey-Fuller (ADF) test to confirm Time series is Non-Stationary

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(df_daily['ElecPrice'])
print(f'ADF Statistic = {result[0]}')
print(f'p-value = {result[1]}')
print(f'Number of lags used = {result[2]}')
print(f'Number of Observations = {result[3]}')
print('critical values are: ')
for f, v in result[4].items():
    print(f'{f} : {v}')
# Out:
# ADF Statistic = -3.8539708618723143
# p-value = 0.002400959110982094
# Number of lags used = 1
# Number of Observations = 124
# critical values are:
# 1% : -3.484219653271961
# 5% : -2.885145235641637
# 10% : -2.579359138917794

# %% [markdown]
# Since p-value (0.0024) < 0.05 and ADF Statistic is lesser than 5% critical value, then the series is indeed <strong>Stationary</strong>.

# %% [markdown]
# ##### Assigning ds and y values

# %% [markdown]
# First, make a copy of df_daily and reset index

# %%
df_daily_copy = df_daily.copy().reset_index()
df_daily_copy.head()
# Out:
#     FullDate       Tmax      SysLoad  GasPrice   ElecPrice
# 0 2010-09-30  16.906667  1578.145819  3.578663   25.075896
# 1 2010-10-31  21.377419  1398.027708  2.799987   22.223629
# 2 2010-11-30  24.323333  1484.759104  2.321943   22.575944
# 3 2010-12-31  26.696774  1082.167586  2.401429   17.585753
# 4 2011-01-31  30.629032  1331.477822  2.917977  103.094603

# %% [markdown]
# Selecting columns FullDate and ElecPrice and renaming to ds and y respectively

# %%
df_daily_copy = df_daily_copy[['FullDate', 'ElecPrice']].rename(columns = {'FullDate' : 'ds', 'ElecPrice' : 'y'})
df_daily_copy.head()
# Out:
#           ds           y
# 0 2010-09-30   25.075896
# 1 2010-10-31   22.223629
# 2 2010-11-30   22.575944
# 3 2010-12-31   17.585753
# 4 2011-01-31  103.094603

# %% [markdown]
# ##### Splitting dataset into train & test set, such that train = first 2757 days and test = datasetlength - 2757

# %%
x_train, x_test = df_daily_copy.ds[:2757], df_daily_copy.ds[2757:]
x_train.head()
# Out:
# 0   2010-09-30
# 1   2010-10-31
# 2   2010-11-30
# 3   2010-12-31
# 4   2011-01-31
# Name: ds, dtype: datetime64[ns]

# %%
y_train, y_test = df_daily_copy.y[:2757], df_daily_copy.y[2757:]
y_train.head()
# Out:
# 0     25.075896
# 1     22.223629
# 2     22.575944
# 3     17.585753
# 4    103.094603
# Name: y, dtype: float64

# %% [markdown]
# ##### To train model using Facebook Prophet

# %% [markdown]
# Import Facebook Prophet

# %%
from fbprophet import Prophet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/bf/4vw065691fq09r8fywxk85980000gn/T/ipykernel_9648/1130067940.py in <module>
# ----> 1 from fbprophet import Prophet
#
# ModuleNotFoundError: No module named 'fbprophet'
